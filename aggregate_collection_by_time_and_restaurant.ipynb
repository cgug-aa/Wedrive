# %%
from dotenv import load_dotenv
from pymongo import MongoClient
import pandas as pd
import os
from pyproj import Transformer

# %% [markdown]
# #### 데이터베이스 연결

# %%
# 데이터베이스 연결
load_dotenv()
client = MongoClient(os.getenv('DB_ADR'),
          username=os.getenv('DB_USER'),
          password=os.getenv('DB_PASSWORD'),
          authSource=os.getenv('DB_AuthSource'),
          authMechanism=os.getenv('DB_AuthMechanism'))

db = client.get_database(os.getenv('DB_Collection'))

# 좌표 변환기 설정 (EPSG:5174 -> EPSG:4326)
transformer = Transformer.from_crs("EPSG:5174", "EPSG:4326", always_xy=True)

# %% [markdown]
# #### 사용 함수

# %%
# raw_od_uuid 컬렉션에서 시간 필터링('11', '12', '18', '19')
def timefilter(raw_cl, timefiltered_cl):
    target_values=['11', '12', '18', '19']
    regex_pattern = f"^.{{11}}({'|'.join(target_values)}).*$"

    tgt_data=list(raw_cl.find({"time_end": {"$regex":regex_pattern}},{
        '_id':False,
        'uuid':True,
        'time_end':True,
        'destination_lat':True,
        'destination_lng':True}))
    print(len(tgt_data))
    timefiltered_cl.insert_many(tgt_data)

# %%
def public_docs_append_field_4326(public_cl_list):
    for public_cl in public_cl_list:
        public_collection=db.get_collection(public_cl)
        for public in public_collection.find():
            lat2, lng2 = public['좌표정보x(epsg5174)'], public['좌표정보y(epsg5174)']
            if lat2 is not None and lng2 is not None:
                lng2, lat2 = transformer.transform(lat2, lng2)
                public_collection.update_one(
                    {'_id': public['_id']},
                    {'$set': {'좌표정보x(epsg4326)': lat2, '좌표정보y(epsg4326)': lng2}}
                 )

# %%
pipeline_04 = [
    {
        '$lookup': {
            'from': 'public_open_04',
            'let': {
                'lat1': '$destination_lat',
                'lng1': '$destination_lng'
            },
            'pipeline': [
                {
                    '$match': {
                        '$expr': {
                            '$and': [
                                {'$lt': [{'$abs': {'$subtract': ['$좌표정보x(epsg4326)', '$$lat1']}}, 0.0001]},
                                {'$lt': [{'$abs': {'$subtract': ['$좌표정보y(epsg4326)', '$$lng1']}}, 0.0001]}
                            ]
                        },
                        # NaN 값이 아닌 경우만 필터링
                        '좌표정보x(epsg4326)': {'$nin': [float('NaN')]},
                        '좌표정보y(epsg4326)': {'$nin': [float('NaN')]}
                    }
                },
                {
                    '$project': {
                        '_id': 0,
                        '소재지전체주소': 1,
                        '도로명전체주소': 1,
                        '사업장명': 1
                    }
                }
            ],
            'as': 'matched_docs'
        }
    },
    {
        '$match': {
            'matched_docs': {'$ne': []}  # 매칭된 데이터가 있는 경우만 필터링
        }
    },
    {
        '$project': {
            '_id': 0,
            'uuid': 1,
            'time_end': 1,
            'destination_lat': 1,
            'destination_lng': 1,
            '소재지전체주소': '$matched_docs.소재지전체주소',
            '도로명전체주소': '$matched_docs.도로명전체주소',
            '사업장명': '$matched_docs.사업장명'
        }
    }
]

pipeline_05 = [
    {
        '$lookup': {
            'from': 'public_open_05',
            'let': {
                'lat1': '$destination_lat',
                'lng1': '$destination_lng'
            },
            'pipeline': [
                {
                    '$match': {
                        '$expr': {
                            '$and': [
                                {'$lt': [{'$abs': {'$subtract': ['$좌표정보x(epsg4326)', '$$lat1']}}, 0.0001]},
                                {'$lt': [{'$abs': {'$subtract': ['$좌표정보y(epsg4326)', '$$lng1']}}, 0.0001]}
                            ]
                        },
                        # NaN 값이 아닌 경우만 필터링
                        '좌표정보x(epsg4326)': {'$nin': [float('NaN')]},
                        '좌표정보y(epsg4326)': {'$nin': [float('NaN')]}
                    }
                },
                {
                    '$project': {
                        '_id': 0,
                        '소재지전체주소': 1,
                        '도로명전체주소': 1,
                        '사업장명': 1
                    }
                }
            ],
            'as': 'matched_docs'
        }
    },
    {
        '$match': {
            'matched_docs': {'$ne': []}  # 매칭된 데이터가 있는 경우만 필터링
        }
    },
    {
        '$project': {
            '_id': 0,
            'uuid': 1,
            'time_end': 1,
            'destination_lat': 1,
            'destination_lng': 1,
            '소재지전체주소': '$matched_docs.소재지전체주소',
            '도로명전체주소': '$matched_docs.도로명전체주소',
            '사업장명': '$matched_docs.사업장명'
        }
    }
]

# %%
tgt_data=list(db["public_open_04"].find({'좌표정보x(epsg4326)':float('NaN')}))
len(tgt_data)

# %% [markdown]
# #### 실행 코드

# %%
#2020~23년도 필터링 후 데이터 삽입
raw_cls=['raw_od_uuid_2023', 'raw_od_uuid_2022', 'raw_od_uuid_2021', 'raw_od_uuid_2020']
timefilterd_cls=['timefiltered_2023', 'timefiltered_2022', 'timefiltered_2021', 'timefiltered_2020']

for raw, time in zip(raw_cls, timefilterd_cls):
    raw_cl = db.get_collection(raw)
    timefiltered_cl = db.get_collection(time)
    timefilter(raw_cl,timefiltered_cl)


# public 컬렉션 데이터에 변환된 좌표 추가
collections_to_check = ["public_open_04", "public_open_05"]
public_docs_append_field_4326(collections_to_check)

# %% [markdown]
# ##### 필터링 데이터 개수
# ||2023|2022|2021|2020|
# |---|---|---|---|---|
# |개수|5,909,489|7,527,799|8,627,310|8,907,064|

# %%
result_collection = db.get_collection("user_destination_restaurant_timefiltering_20~23")
batch_size = 100000
last_id = None 

total_count = db["raw_test_1"].count_documents({})
print(total_count)
for processed in range(0, total_count, batch_size):
    print(f"{processed}번째 문서부터 {processed + batch_size}번째 문서까지 처리 중...")
    
    batch_pipeline = [
        {"$sort": {"_id": 1}},
        {"$skip": processed},
        {"$limit": batch_size}, 
    ] + pipeline_04 

    batch_docs = list(db["raw_test_1"].aggregate(batch_pipeline))
    
    if batch_docs:
        print(f"{len(batch_docs)}개의 문서 저장")
        result_collection.insert_many(batch_docs)
    else:
        print("해당 구간에는 조건에 맞는 데이터가 없음")
# Out:
# 8475695
# 0번째 문서부터 100000번째 문서까지 처리 중...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 16
#       8 print(f"{processed}번째 문서부터 {processed + batch_size}번째 문서까지 처리 중...")
#      10 batch_pipeline = [
#      11     {"$sort": {"_id": 1}},
#      12     {"$skip": processed},
#      13     {"$limit": batch_size},
#      14 ] + pipeline_04
# ---> 16 batch_docs = list(db["raw_test_1"].aggregate(batch_pipeline))
#      18 if batch_docs:
#      19     print(f"{len(batch_docs)}개의 문서 저장")
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\command_cursor.py:340, in CommandCursor.__next__(self)
#     339 def __next__(self) -> _DocumentType:
# --> 340     return self.next()
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\command_cursor.py:333, in CommandCursor.next(self)
#     331 # Block until a document is returnable.
#     332 while self.alive:
# --> 333     doc = self._try_next(True)
#     334     if doc is not None:
#     335         return doc
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\command_cursor.py:345, in CommandCursor._try_next(self, get_more_allowed)
#     343 """Advance the cursor blocking for at most one getMore command."""
#     344 if not len(self._data) and not self._killed and get_more_allowed:
# --> 345     self._refresh()
#     346 if len(self._data):
#     347     return self._data.popleft()
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\command_cursor.py:305, in CommandCursor._refresh(self)
#     303     dbname, collname = self._ns.split(".", 1)
#     304     read_pref = self._collection._read_preference_for(self.session)
# --> 305     self._send_message(
#     306         self._getmore_class(
#     307             dbname,
#     308             collname,
#     309             self._batch_size,
#     310             self._id,
#     311             self._collection.codec_options,
#     312             read_pref,
#     313             self._session,
#     314             self._collection.database.client,
#     315             self._max_await_time_ms,
#     316             self._sock_mgr,
#     317             False,
#     318             self._comment,
#     319         )
#     320     )
#     321 else:  # Cursor id is zero nothing else to return
#     322     self._die_lock()
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\command_cursor.py:252, in CommandCursor._send_message(self, operation)
#     250 client = self._collection.database.client
#     251 try:
# --> 252     response = client._run_operation(
#     253         operation, self._unpack_response, address=self._address
#     254     )
#     255 except OperationFailure as exc:
#     256     if exc.code in _CURSOR_CLOSED_ERRORS:
#     257         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\mongo_client.py:1754, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1744     operation.reset()  # Reset op in case of retry.
#    1745     return server.run_operation(
#    1746         conn,
#    1747         operation,
#    (...)
#    1751         self,
#    1752     )
# -> 1754 return self._retryable_read(
#    1755     _cmd,
#    1756     operation.read_preference,
#    1757     operation.session,  # type: ignore[arg-type]
#    1758     address=address,
#    1759     retryable=isinstance(operation, _Query),
#    1760     operation=operation.name,
#    1761 )
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\mongo_client.py:1863, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1858 # Ensure that the client supports retrying on reads and there is no session in
#    1859 # transaction, otherwise, we will not support retry behavior for this call.
#    1860 retryable = bool(
#    1861     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1862 )
# -> 1863 return self._retry_internal(
#    1864     func,
#    1865     session,
#    1866     None,
#    1867     operation,
#    1868     is_read=True,
#    1869     address=address,
#    1870     read_pref=read_pref,
#    1871     retryable=retryable,
#    1872     operation_id=operation_id,
#    1873 )
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\mongo_client.py:1830, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1793 @_csot.apply
#    1794 def _retry_internal(
#    1795     self,
#    (...)
#    1804     operation_id: Optional[int] = None,
#    1805 ) -> T:
#    1806     """Internal retryable helper for all client transactions.
#    1807
#    1808     :param func: Callback function we want to retry
#    (...)
#    1817     :return: Output of the calling func()
#    1818     """
#    1819     return _ClientConnectionRetryable(
#    1820         mongo_client=self,
#    1821         func=func,
#    1822         bulk=bulk,
#    1823         operation=operation,
#    1824         is_read=is_read,
#    1825         session=session,
#    1826         read_pref=read_pref,
#    1827         address=address,
#    1828         retryable=retryable,
#    1829         operation_id=operation_id,
# -> 1830     ).run()
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\mongo_client.py:2554, in _ClientConnectionRetryable.run(self)
#    2552 self._check_last_error(check_csot=True)
#    2553 try:
# -> 2554     return self._read() if self._is_read else self._write()
#    2555 except ServerSelectionTimeoutError:
#    2556     # The application may think the write was never attempted
#    2557     # if we raise ServerSelectionTimeoutError on the retry
#    2558     # attempt. Raise the original exception instead.
#    2559     self._check_last_error()
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\mongo_client.py:2697, in _ClientConnectionRetryable._read(self)
#    2695 if self._retrying and not self._retryable:
#    2696     self._check_last_error()
# -> 2697 return self._func(self._session, self._server, conn, read_pref)
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\mongo_client.py:1745, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1738 def _cmd(
#    1739     _session: Optional[ClientSession],
#    1740     server: Server,
#    1741     conn: Connection,
#    1742     read_preference: _ServerMode,
#    1743 ) -> Response:
#    1744     operation.reset()  # Reset op in case of retry.
# -> 1745     return server.run_operation(
#    1746         conn,
#    1747         operation,
#    1748         read_preference,
#    1749         self._event_listeners,
#    1750         unpack_res,
#    1751         self,
#    1752     )
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\helpers.py:45, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      42 from pymongo.synchronous.pool import Connection
#      44 try:
# ---> 45     return func(*args, **kwargs)
#      46 except OperationFailure as exc:
#      47     if no_reauth:
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\server.py:208, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res, client)
#     206 else:
#     207     conn.send_message(data, max_doc_size)
# --> 208     reply = conn.receive_message(request_id)
#     210 # Unpack and check for command errors.
#     211 if use_cmd:
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\pool.py:592, in Connection.receive_message(self, request_id)
#     590     return receive_message(self, request_id, self.max_message_size)
#     591 except BaseException as error:
# --> 592     self._raise_connection_failure(error)
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\pool.py:590, in Connection.receive_message(self, request_id)
#     585 """Receive a raw BSON message or raise ConnectionFailure.
#     586
#     587 If any exception is raised, the socket is closed.
#     588 """
#     589 try:
# --> 590     return receive_message(self, request_id, self.max_message_size)
#     591 except BaseException as error:
#     592     self._raise_connection_failure(error)
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\network.py:320, in receive_message(conn, request_id, max_message_size)
#     318         deadline = None
#     319 # Ignore the response's request id.
# --> 320 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     321 # No request_id for exhaust cursor "getMore".
#     322 if request_id is not None:
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\network.py:390, in _receive_data_on_socket(conn, length, deadline)
#     388 while bytes_read < length:
#     389     try:
# --> 390         wait_for_read(conn, deadline)
#     391         # CSOT: Update timeout. When the timeout has expired perform one
#     392         # final non-blocking recv. This helps avoid spurious timeouts when
#     393         # the response is actually already buffered on the client.
#     394         if _csot.get_timeout() and deadline is not None:
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\network.py:375, in wait_for_read(conn, deadline)
#     373     else:
#     374         timeout = _POLL_TIMEOUT
# --> 375     readable = conn.socket_checker.select(sock, read=True, timeout=timeout)
#     376 if conn.cancel_context.cancelled:
#     377     raise _OperationCancelled("operation cancelled")
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\socket_checker.py:77, in SocketChecker.select(self, sock, read, write, timeout)
#      75 rlist = [sock] if read else []
#      76 wlist = [sock] if write else []
# ---> 77 res = select.select(rlist, wlist, [sock], timeout)
#      78 # select returns a 3-tuple of lists of objects that are
#      79 # ready: subsets of the first three arguments. Return
#      80 # True if any of the lists are not empty.
#      81 return any(res)
#
# KeyboardInterrupt:

# %%
result_collection = db.get_collection("user_destination_restaurant_timefiltering_2022")
batch_size = 100
last_id = None 

total_count = db["timefiltered_2022"].count_documents({})
print(total_count)
for processed in range(0, total_count, batch_size):
    print(f"{processed}번째 문서부터 {processed + batch_size}번째 문서까지 처리 중...")
    
    batch_pipeline = [
        {"$sort": {"_id": 1}},
        {"$skip": processed},
        {"$limit": batch_size}, 
    ] + pipeline_05 

    batch_docs = list(db["timefiltered_2022"].aggregate(batch_pipeline))
    
    if batch_docs:
        print(f"{len(batch_docs)}개의 문서 저장")
        result_collection.insert_many(batch_docs)
    else:
        print("해당 구간에는 조건에 맞는 데이터가 없음")

# %%
pipeline_optimized = [
    {
        '$lookup': {
            'from': 'public_open_04',
            'let': {
                'lat1': '$destination_lat',
                'lng1': '$destination_lng'
            },
            'pipeline': [
                {
                    '$match': {
                        '$expr': {
                            '$and': [
                                {'$lt': [{'$abs': {'$subtract': ['$좌표정보x(epsg4326)', '$$lat1']}}, 0.0001]},
                                {'$lt': [{'$abs': {'$subtract': ['$좌표정보y(epsg4326)', '$$lng1']}}, 0.0001]}
                            ]
                        },
                        '좌표정보x(epsg4326)': {'$nin': [float('NaN')]},
                        '좌표정보y(epsg4326)': {'$nin': [float('NaN')]}
                    }
                },
                {
                    '$project': {
                        '_id': 0,
                        '소재지전체주소': 1,
                        '도로명전체주소': 1,
                        '사업장명': 1
                    }
                }
            ],
            'as': 'matched_docs'
        }
    },
    {
        '$match': {
            'matched_docs': {'$ne': []}  # 매칭된 데이터만 유지
        }
    },
    {
        '$project': {
            '_id': 0,
            'uuid': 1,
            'time_end': 1,
            'destination_lat': 1,
            'destination_lng': 1,
            '소재지전체주소': {'$arrayElemAt': ['$matched_docs.소재지전체주소', 0]},
            '도로명전체주소': {'$arrayElemAt': ['$matched_docs.도로명전체주소', 0]},
            '사업장명': {'$arrayElemAt': ['$matched_docs.사업장명', 0]}
        }
    },
    {
        '$merge': {
            'into': 'user_destination_restaurant_timefiltering_2022_2',  # 결과 저장할 컬렉션
            'on': '_id',                # 기존 `_id` 기준으로 병합 (업데이트)
            'whenMatched': 'merge',     # 기존 문서 있으면 업데이트
            'whenNotMatched': 'insert'  # 없으면 새로 삽입
        }
    }
]

db["timefiltered_2022"].aggregate(pipeline_optimized)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 61
#       1 pipeline_optimized = [
#       2     {
#       3         '$lookup': {
#    (...)
#      58     }
#      59 ]
# ---> 61 db["timefiltered_2022"].aggregate(pipeline_optimized)
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\collection.py:2958, in Collection.aggregate(self, pipeline, session, let, comment, **kwargs)
#    2882 """Perform an aggregation using the aggregation framework on this
#    2883 collection.
#    2884
#    (...)
#    2955     https://mongodb.com/docs/manual/reference/command/aggregate
#    2956 """
#    2957 with self._database.client._tmp_session(session, close=False) as s:
# -> 2958     return self._aggregate(
#    2959         _CollectionAggregationCommand,
#    2960         pipeline,
#    2961         CommandCursor,
#    2962         session=s,
#    2963         explicit_session=session is not None,
#    2964         let=let,
#    2965         comment=comment,
#    2966         **kwargs,
#    2967     )
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\collection.py:2866, in Collection._aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, let, comment, **kwargs)
#    2855     kwargs["comment"] = comment
#    2856 cmd = aggregation_command(
#    2857     self,
#    2858     cursor_class,
#    (...)
#    2863     user_fields={"cursor": {"firstBatch": 1}},
#    2864 )
# -> 2866 return self._database.client._retryable_read(
#    2867     cmd.get_cursor,
#    2868     cmd.get_read_preference(session),  # type: ignore[arg-type]
#    2869     session,
#    2870     retryable=not cmd._performs_write,
#    2871     operation=_Op.AGGREGATE,
#    2872 )
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\mongo_client.py:1863, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1858 # Ensure that the client supports retrying on reads and there is no session in
#    1859 # transaction, otherwise, we will not support retry behavior for this call.
#    1860 retryable = bool(
#    1861     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1862 )
# -> 1863 return self._retry_internal(
#    1864     func,
#    1865     session,
#    1866     None,
#    1867     operation,
#    1868     is_read=True,
#    1869     address=address,
#    1870     read_pref=read_pref,
#    1871     retryable=retryable,
#    1872     operation_id=operation_id,
#    1873 )
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\mongo_client.py:1830, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1793 @_csot.apply
#    1794 def _retry_internal(
#    1795     self,
#    (...)
#    1804     operation_id: Optional[int] = None,
#    1805 ) -> T:
#    1806     """Internal retryable helper for all client transactions.
#    1807
#    1808     :param func: Callback function we want to retry
#    (...)
#    1817     :return: Output of the calling func()
#    1818     """
#    1819     return _ClientConnectionRetryable(
#    1820         mongo_client=self,
#    1821         func=func,
#    1822         bulk=bulk,
#    1823         operation=operation,
#    1824         is_read=is_read,
#    1825         session=session,
#    1826         read_pref=read_pref,
#    1827         address=address,
#    1828         retryable=retryable,
#    1829         operation_id=operation_id,
# -> 1830     ).run()
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\mongo_client.py:2554, in _ClientConnectionRetryable.run(self)
#    2552 self._check_last_error(check_csot=True)
#    2553 try:
# -> 2554     return self._read() if self._is_read else self._write()
#    2555 except ServerSelectionTimeoutError:
#    2556     # The application may think the write was never attempted
#    2557     # if we raise ServerSelectionTimeoutError on the retry
#    2558     # attempt. Raise the original exception instead.
#    2559     self._check_last_error()
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\mongo_client.py:2697, in _ClientConnectionRetryable._read(self)
#    2695 if self._retrying and not self._retryable:
#    2696     self._check_last_error()
# -> 2697 return self._func(self._session, self._server, conn, read_pref)
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\aggregation.py:164, in _AggregationCommand.get_cursor(self, session, server, conn, read_preference)
#     161     write_concern = None
#     163 # Run command.
# --> 164 result = conn.command(
#     165     self._database.name,
#     166     cmd,
#     167     read_preference,
#     168     self._target.codec_options,
#     169     parse_write_concern_error=True,
#     170     read_concern=read_concern,
#     171     write_concern=write_concern,
#     172     collation=self._collation,
#     173     session=session,
#     174     client=self._database.client,
#     175     user_fields=self._user_fields,
#     176 )
#     178 if self._result_processor:
#     179     self._result_processor(result, conn)
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\helpers.py:45, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      42 from pymongo.synchronous.pool import Connection
#      44 try:
# ---> 45     return func(*args, **kwargs)
#      46 except OperationFailure as exc:
#      47     if no_reauth:
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\pool.py:566, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     564 # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     565 except BaseException as error:
# --> 566     self._raise_connection_failure(error)
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\pool.py:538, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     536     self._raise_if_not_writable(unacknowledged)
#     537 try:
# --> 538     return command(
#     539         self,
#     540         dbname,
#     541         spec,
#     542         self.is_mongos,
#     543         read_preference,
#     544         codec_options,
#     545         session,
#     546         client,
#     547         check,
#     548         allowable_errors,
#     549         self.address,
#     550         listeners,
#     551         self.max_bson_size,
#     552         read_concern,
#     553         parse_write_concern_error=parse_write_concern_error,
#     554         collation=collation,
#     555         compression_ctx=self.compression_context,
#     556         use_op_msg=self.op_msg_enabled,
#     557         unacknowledged=unacknowledged,
#     558         user_fields=user_fields,
#     559         exhaust_allowed=exhaust_allowed,
#     560         write_concern=write_concern,
#     561     )
#     562 except (OperationFailure, NotPrimaryError):
#     563     raise
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\network.py:208, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     206     response_doc: _DocumentOut = {"ok": 1}
#     207 else:
# --> 208     reply = receive_message(conn, request_id)
#     209     conn.more_to_come = reply.more_to_come
#     210     unpacked_docs = reply.unpack_response(
#     211         codec_options=codec_options, user_fields=user_fields
#     212     )
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\network.py:320, in receive_message(conn, request_id, max_message_size)
#     318         deadline = None
#     319 # Ignore the response's request id.
# --> 320 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     321 # No request_id for exhaust cursor "getMore".
#     322 if request_id is not None:
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\network.py:390, in _receive_data_on_socket(conn, length, deadline)
#     388 while bytes_read < length:
#     389     try:
# --> 390         wait_for_read(conn, deadline)
#     391         # CSOT: Update timeout. When the timeout has expired perform one
#     392         # final non-blocking recv. This helps avoid spurious timeouts when
#     393         # the response is actually already buffered on the client.
#     394         if _csot.get_timeout() and deadline is not None:
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\synchronous\network.py:375, in wait_for_read(conn, deadline)
#     373     else:
#     374         timeout = _POLL_TIMEOUT
# --> 375     readable = conn.socket_checker.select(sock, read=True, timeout=timeout)
#     376 if conn.cancel_context.cancelled:
#     377     raise _OperationCancelled("operation cancelled")
#
# File c:\Users\11\anaconda3\envs\wedrive\Lib\site-packages\pymongo\socket_checker.py:77, in SocketChecker.select(self, sock, read, write, timeout)
#      75 rlist = [sock] if read else []
#      76 wlist = [sock] if write else []
# ---> 77 res = select.select(rlist, wlist, [sock], timeout)
#      78 # select returns a 3-tuple of lists of objects that are
#      79 # ready: subsets of the first three arguments. Return
#      80 # True if any of the lists are not empty.
#      81 return any(res)
#
# KeyboardInterrupt:
